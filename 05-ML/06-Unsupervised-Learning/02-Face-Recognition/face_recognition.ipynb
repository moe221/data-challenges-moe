# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PCA-:-Face-Recognition" data-toc-modified-id="PCA-:-Face-Recognition-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>PCA : Face Recognition</a></span><ul class="toc-item"><li><span><a href="#Load-dataset" data-toc-modified-id="Load-dataset-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load dataset</a></span></li><li><span><a href="#Compress-images-with-PCA" data-toc-modified-id="Compress-images-with-PCA-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Compress images with PCA</a></span><ul class="toc-item"><li><span><a href="#🧪-Test-your-code" data-toc-modified-id="🧪-Test-your-code-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>🧪 Test your code</a></span></li></ul></li><li><span><a href="#Investigate-your-Principal-Components" data-toc-modified-id="Investigate-your-Principal-Components-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Investigate your Principal Components</a></span></li><li><span><a href="#How-to-Choose-the-Number-of-Components?" data-toc-modified-id="How-to-Choose-the-Number-of-Components?-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>How to Choose the Number of Components?</a></span><ul class="toc-item"><li><span><a href="#🧪-Test-your-code" data-toc-modified-id="🧪-Test-your-code-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>🧪 Test your code</a></span></li></ul></li><li><span><a href="#Classify-images-(PCA-as-feature-engineering)" data-toc-modified-id="Classify-images-(PCA-as-feature-engineering)-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Classify images (PCA as feature engineering)</a></span><ul class="toc-item"><li><span><a href="#Train-test-split-the-face-dataset" data-toc-modified-id="Train-test-split-the-face-dataset-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Train test split the face dataset</a></span></li><li><span><a href="#Transform-your-training-set-to-reduce-the-number-of-dimensions-/-features" data-toc-modified-id="Transform-your-training-set-to-reduce-the-number-of-dimensions-/-features-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Transform your training set to reduce the number of dimensions / features</a></span></li><li><span><a href="#Cross-validate-your-choice-of-best-hyperparameters" data-toc-modified-id="Cross-validate-your-choice-of-best-hyperparameters-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Cross validate your choice of best hyperparameters</a></span></li><li><span><a href="#🧪-Test-your-code" data-toc-modified-id="🧪-Test-your-code-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>🧪 Test your code</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # PCA : Face Recognition

# %% [markdown]
# In this challenge, we will use PCA in combination with a dataset of multiple black & white image**s**
#
# This time then:
# - each image is an observation (sample)
# - each pixel's luminosity level is a feature (lots of features!!)
#
# We will use PCA to compress the picture by reducing the number of feature used to describe it.

# %% [markdown]
# ## Load dataset
#
# Using PCA for dimensionality reduction involves zeroing out one or more of the smallest principal components, resulting in a **lower-dimensional projection** of the data that preserves the maximal data variance.
#
# We can then use those new representations as features to feed any model we want. It can be very useful since you often have lots of features, and you want to transform and keep a packed number of features that are the most representative of what you want to model.
#
# __Lets load a face image dataset and apply PCA.__

# %%
# Load data
from sklearn.datasets import fetch_lfw_people
faces = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# %% [markdown]
# You have access to
# - `faces.images` which are the matrix of __50 x 37 pixels__ you can plot
# - `faces.data` for the the flattened version in  of size __1850 x 1__ (because 50 x 37 = 1850).
# - `faces.target` which is annotation of every face to the corresponding person (as a number index)

# %%
# 1288 images
faces.images.shape
# Out:
# (1288, 50, 37)

# %%
# 1288 images flattened, equivalent to to faces.images.reshape(1288,1850)
faces.data.shape
# Out:
# (1288, 1850)

# %%
faces.target
# Out:
# array([5, 6, 3, ..., 5, 3, 5])

# %%
# Let’s visualize some faces.
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(7,10))
for i in range(15):
    plt.subplot(5, 5, i + 1)
    plt.title(faces.target_names[faces.target[i]], size=12)
    plt.imshow(faces.images[i], cmap=plt.cm.gray)
    plt.xticks(())
    plt.yticks(())

# %% [markdown]
# ## Compress images with PCA

# %% [markdown]
# In this scikit dataset we have 50 × 37 pixel images (1850 dimensions!). Often, so many dimensions is a lot to train algorithms we studied in the previous exercises (for example SVM).
#
# That's why we use PCA to reduce these features to a more manageable size, while maintaining most of the information of the dataset.
#
# __👉 Apply PCA to the dataset (both fit and transform), to reduce dimensions to 150, by setting `n_components=150`__. Put your transformation into a variable named `data_projected`

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=150)
data_projected = pca.fit_transform(faces.data)

# %% [markdown]
# The face dataset was projected onto only the first 150 principal components! Again, what we call components are directions of most variance of the dataset.
#
# It means that now, we don't need 1850 pixels anymore to describe each images but just 150 values. A gain by factor 12.
#
# __How is that possible?__
#
# - The pca has found to be the most representative directions of what distinguishes faces between each other with just 150 values for every image.
#
# - They are the directions of most variance.
#
# - You can access them in `pca.components_`
#
# 👉  Look at the first component of this array of components, and its shape

# %%
pca.components_[0]
# Out:
# array([-0.00681695, -0.00736357, -0.00855026, ..., -0.01404509,
#        -0.011956  , -0.00964077], dtype=float32)

# %% [markdown]
# As you can see, it's a vector of 1850 values. We have now 150 components of 1850 values each.
#
# One face is now described as a combination (sum) of those components.
#
# Let's reconstruct one image from its reduced representation to see how it works.
#
# 👉 Use `inverse_transform` on your `data_projected` to reconstruct a `data_reconstructed` dataset

# %%
data_reconstructed = pca.inverse_transform(data_projected)

# %% [markdown]
# 👉 Plot the 13th picture (Gearge W Bush) of the reconstructed dataset, and compare it with the original one.
#
# <details>
#     <summary>💡Hint</summary>
#
# You'll have to reshape the flattened data into an "image" of dimension 2
# </details>

# %%
data_reshaped = data_reconstructed.reshape(1288, 50, 37)
plt.imshow(data_reshaped[12])

# %% [markdown]
# ### 🧪 Test your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('projection', shape=data_projected.shape)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/Moe/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/Moe/code/moe221/data-challenges-moe/05-ML/06-Unsupervised-Learning/02-Face-Recognition
# plugins: dash-2.0.0, anyio-3.3.2, cov-3.0.0
# collecting ... collected 1 item
#
# tests/test_projection.py::TestProjection::test_shape PASSED              [100%]
#
# ============================== 1 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/projection.pickle
#
# git commit -m 'Completed projection step'
#
# git push origin master

# %% [markdown]
# 👉 (Optional) study the code below which reconstruct the image step by step without `inverse_transform`.
#
# Instead, we do manually the multiplication $X_{reconstructed} = X_{projected} W$ with $W$ being the `pca.components_` matrix of 150 PC in rows expressed as linear combination of 1850 pixels in columns

# %%
num_dimensions = 150

# We do our reconstruction over the 13th image
image_original = faces.images[12];
image_compressed = data_projected[12];

# we start the reconstruction from the mean over all images (feel free to print mean face to check!)
image_reconstructed = pca.mean_.copy(); 

# Then, reconstruct the image by doing the sum of every 150 entry of its compressed representation,
# weighted by the corresponding principal components
for i in range(num_dimensions):
    image_reconstructed += pca.components_[i] * image_compressed[i]
    
# Plot the original and the compressed image.
fig, ax = plt.subplots(1, 2, figsize = (5,5))
ax[0].imshow(image_original, cmap=plt.cm.gray)
ax[0].set_title('Original Image')
ax[1].imshow(image_reconstructed.reshape(faces.images[0].shape), cmap=plt.cm.gray)
ax[1].set_title('Compressed reconstructed Image')
for ax in fig.axes:
    ax.axis('off')
plt.tight_layout()

# %% [markdown]
# ## Investigate your Principal Components

# %% [markdown]
# 👉 Image-plot the "mean" face of the dataset
#
# <details>
#     <summary>💡Hint</summary>
#
#
# You can use `pca.mean_` or `faces.data.mean(axis=0)`
# </details>

# %%
plt.imshow(pca.mean_.reshape(50, 37))

# %% [markdown]
# 👉 Access your first PC. What's its shape? Print it as pd.Series or NDarray. What does each values represents?

# %%
pca.components_[0].shape
# Out:
# (1850,)

# %% [markdown]
# Each PC is a flatten "image" of 1850 pixels
#
# - Your first PC are the most important "directions" on of your 1850-dimension dataset.
#
# - They are the most important "linear combination of your 1850 pixels".
#
# - The ones which preserves the most "variance" when your dataset of pictures is projected onto it.
#
# - The first few PCs are the regions of the 2D pixel grid that bear the most differences between your 1288 images

# %% [markdown]
# 👉 Image-Plot the **5 first** principal components, as well as the **last** one.
# Do you see more intuitively what PC are?

# %%
plt.imshow(pca.components_[0].reshape(50, 37))

# %%
# YOUR CODE HERE

# %% [markdown]
# Every image can be represented by the "mean face" plus a linear combination of the 150 "PC faces".

# %% [markdown]
# ## How to Choose the Number of Components?
#
# In practice, it is very important to find how many components are needed to describe the data without losing too much information. This can be determined visually by plotting the cumulative sum of `explained_variance_ratio_` as a function of the number of components.
#
# 👉 Plot it below for the first 150 components

# %%
import numpy as np
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.ylim(ymin=0)
plt.title('cumulated share of explained variance')
plt.xlabel('# of principal component used');

# %%
[(index, value) for index, value in enumerate(npplt.cumsum(pca.explained_variance_ratio_)) if value >= 0.8]
# Out:
# [(29, 0.80193466),
#  (30, 0.8058238),
#  (31, 0.80953836),
#  (32, 0.8131471),
#  (33, 0.8166444),
#  (34, 0.82004714),
#  (35, 0.82326627),
#  (36, 0.82644117),
#  (37, 0.82945514),
#  (38, 0.8323663),
#  (39, 0.8351605),
#  (40, 0.8379372),
#  (41, 0.8406582),
#  (42, 0.8432568),
#  (43, 0.8458119),
#  (44, 0.84819233),
#  (45, 0.85054827),
#  (46, 0.85288113),
#  (47, 0.85512507),
#  (48, 0.857317),
#  (49, 0.8594792),
#  (50, 0.8615862),
#  (51, 0.86363465),
#  (52, 0.8656207),
#  (53, 0.8675511),
#  (54, 0.869476),
#  (55, 0.87135863),
#  (56, 0.8731469),
#  (57, 0.8749159),
#  (58, 0.87664557),
#  (59, 0.8783593),
#  (60, 0.87999344),
#  (61, 0.8815889),
#  (62, 0.88315207),
#  (63, 0.884675),
#  (64, 0.886177),
#  (65, 0.8876358),
#  (66, 0.8890699),
#  (67, 0.89048535),
#  (68, 0.89188194),
#  (69, 0.89327323),
#  (70, 0.8946075),
#  (71, 0.8959092),
#  (72, 0.89720565),
#  (73, 0.8984658),
#  (74, 0.8996986),
#  (75, 0.90091974),
#  (76, 0.90212196),
#  (77, 0.90330446),
#  (78, 0.90447295),
#  (79, 0.90561694),
#  (80, 0.9067578),
#  (81, 0.90786624),
#  (82, 0.9089733),
#  (83, 0.9100379),
#  (84, 0.9110919),
#  (85, 0.91211706),
#  (86, 0.9131355),
#  (87, 0.9141347),
#  (88, 0.91511244),
#  (89, 0.9160824),
#  (90, 0.91703904),
#  (91, 0.9179763),
#  (92, 0.91889447),
#  (93, 0.9197962),
#  (94, 0.92068034),
#  (95, 0.9215616),
#  (96, 0.92242193),
#  (97, 0.9232623),
#  (98, 0.92409825),
#  (99, 0.92491466),
#  (100, 0.9257254),
#  (101, 0.92651725),
#  (102, 0.9272949),
#  (103, 0.9280589),
#  (104, 0.92880845),
#  (105, 0.929552),
#  (106, 0.9302777),
#  (107, 0.9309923),
#  (108, 0.9316959),
#  (109, 0.93238604),
#  (110, 0.93307334),
#  (111, 0.9337545),
#  (112, 0.93442225),
#  (113, 0.93508583),
#  (114, 0.9357405),
#  (115, 0.93638736),
#  (116, 0.93702066),
#  (117, 0.93763995),
#  (118, 0.9382502),
#  (119, 0.9388511),
#  (120, 0.9394447),
#  (121, 0.94002914),
#  (122, 0.94060045),
#  (123, 0.9411599),
#  (124, 0.94171906),
#  (125, 0.9422618),
#  (126, 0.9427994),
#  (127, 0.94333494),
#  (128, 0.9438633),
#  (129, 0.94438165),
#  (130, 0.9448938),
#  (131, 0.94540197),
#  (132, 0.9459047),
#  (133, 0.9463953),
#  (134, 0.94687927),
#  (135, 0.9473557),
#  (136, 0.9478298),
#  (137, 0.9482919),
#  (138, 0.9487462),
#  (139, 0.94919735),
#  (140, 0.9496435),
#  (141, 0.9500797),
#  (142, 0.95051193),
#  (143, 0.95093644),
#  (144, 0.9513524),
#  (145, 0.9517629),
#  (146, 0.9521676),
#  (147, 0.9525634),
#  (148, 0.9529566),
#  (149, 0.9533466)]

# %% [markdown]
# This curve quantifies how much of the total variance is contained within the first components. For example:
# - The first 20 components contain more than 75% of the variance,
# - while we need about only 70 components to describe 90% of the variance!

# %% [markdown]
# **❓ What is the minimal number of components you need to keep to get _at least_ 80% of the variance?  Assign the value to a variable called `minimal_pc_count`**

# %%
minimal_pc_count = 30

# %% [markdown]
# ### 🧪 Test your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('components', min_pc = minimal_pc_count)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/Moe/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/Moe/code/moe221/data-challenges-moe/05-ML/06-Unsupervised-Learning/02-Face-Recognition
# plugins: dash-2.0.0, anyio-3.3.2, cov-3.0.0
# collecting ... collected 1 item
#
# tests/test_components.py::TestComponents::test_minimal_pc PASSED         [100%]
#
# ============================== 1 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/components.pickle
#
# git commit -m 'Completed components step'
#
# git push origin master

# %% [markdown]
# ## Classify images (PCA as feature engineering)
#
# You have this dataset of faces and you want to build a face recognition engine to predict `faces.target` which is annotation of every face to the corresponding person (as a number index)
#
# You can now use this low-dimensional new transformation you just created, that is still representative of the faces to train your supervised algorithm!

# %% [markdown]
# ### Train test split the face dataset
#
# 👉 Use the train test split function from scikit to separate __the original faces dataset__ into training and testing set, `X_train`, `X_test`, `y_train`, `y_test`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Transform your training set to reduce the number of dimensions / features

# %% [markdown]
# 👉 Fit a PCA __over the training data only__ and transform your training data into the reduced dimension (150 features for example).

# %%
from sklearn.model_selection import train_test_split

X = faces.data
y = faces.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# 👉 Using this same PCA (only trained on the training set) transform your testing set as well

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=150).fit(X_train)
X_train_transformed = pca.transform(X_train)

# %%
X_test_transformed = pca.transform(X_test)

# %% [markdown]
# ### Cross validate your choice of best hyperparameters

# %% [markdown]
# 👉 Call a cross validated grid search for an SVM, where you loop over all combinations of
#
# - kernels
# - "C between 10 and 10000
# - "gamma" between 0.0001 and 0.1
#
# 👉 Use `n_jobs=-1` to make use of all your core CPUs
#
# 👉 Use `f1_weighted` as the performance metric

# %% [markdown]
# <details>
#     <summary>🔎 Hint </summary>
#     Remember the task at hand calls for classification, have a look at the <a src=https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC>Support Vector Classification </a> class.
# </details>

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

param_grid = {
    "kernel": ["linear", "rbf", "sigmoid", "poly"],
    "C": [10, 20, 50, 100, 200, 500, 1000, 2000, 5000],
    "gamma": [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1],
}
clf = GridSearchCV(SVC(class_weight="balanced"), param_grid, cv=5, n_jobs=-1, scoring='f1_weighted')

# %% [markdown]
# 👉 Train that cross validation grid search over our newly transformed training set. (Long computation)

# %%
y_train.shape
# Out:
# (901,)

# %%
# Fit only using 150 PC features instead of 1850 pixels! Much faster! 
clf = clf.fit(X_train_transformed, y_train)
# Out:
# /Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 2000 fits failed out of a total of 2000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=200 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=201 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=202 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=203 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=204 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=205 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=206 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=207 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=208 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=209 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=210 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=211 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=212 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=213 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=214 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=215 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=216 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=217 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=218 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=219 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=220 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=221 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=222 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=223 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=224 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=225 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=226 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=227 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
# ...
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=593 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=594 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=595 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=596 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=597 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=598 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 407, in fit_transform
#     U, S, Vt = self._fit(X)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 457, in _fit
#     return self._fit_full(X, n_components)
#   File "/Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py", line 475, in _fit_full
#     raise ValueError(
# ValueError: n_components=599 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/Moe/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vp/w0q6bwv17zg47jg_mhc4nsdh0000gp/T/ipykernel_17965/917267389.py in <module>
#       1 # Fit only using 150 PC features instead of 1850 pixels! Much faster!
# ----> 2 clf = clf.fit(X_train_transformed, y_train)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     388         """
#     389         fit_params_steps = self._check_fit_params(**fit_params)
# --> 390         Xt = self._fit(X, y, **fit_params_steps)
#     391         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     392             if self._final_estimator != "passthrough":
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     346                 cloned_transformer = clone(transformer)
#     347             # Fit or load from cache the current transformer
# --> 348             X, fitted_transformer = fit_transform_one_cached(
#     349                 cloned_transformer,
#     350                 X,
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891     with _print_elapsed_time(message_clsname, message):
#     892         if hasattr(transformer, "fit_transform"):
# --> 893             res = transformer.fit_transform(X, y, **fit_params)
#     894         else:
#     895             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     405         C-ordered array, use 'np.ascontiguousarray'.
#     406         """
# --> 407         U, S, Vt = self._fit(X)
#     408         U = U[:, : self.n_components_]
#     409
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     455         # Call different fits for either full or truncated SVD
#     456         if self._fit_svd_solver == "full":
# --> 457             return self._fit_full(X, n_components)
#     458         elif self._fit_svd_solver in ["arpack", "randomized"]:
#     459             return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in _fit_full(self, X, n_components)
#     473                 )
#     474         elif not 0 <= n_components <= min(n_samples, n_features):
# --> 475             raise ValueError(
#     476                 "n_components=%r must be between 0 and "
#     477                 "min(n_samples, n_features)=%r with "
#
# ValueError: n_components=200 must be between 0 and min(n_samples, n_features)=150 with svd_solver='full'

# %% [markdown]
# 👉 Print the [classification report](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html#sklearn.metrics.classification_report) of your best model over the testing set

# %%
clf.best_estimator_
# Out:
# SVC(C=10, class_weight='balanced', gamma=0.0001, kernel='linear')

# %%
from sklearn.metrics import classification_report
y_pred = clf.best_estimator_.predict(X_test_transformed)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.55      0.60        22
#            1       0.77      0.81      0.79        72
#            2       0.58      0.71      0.64        31
#            3       0.84      0.85      0.84       172
#            4       0.75      0.68      0.71        31
#            5       0.75      0.56      0.64        16
#            6       0.76      0.74      0.75        43
#
#     accuracy                           0.78       387
#    macro avg       0.73      0.70      0.71       387
# weighted avg       0.78      0.78      0.77       387

# %% [markdown]
# 👉 Try to improve this score with the best choice of PCA components

# %% [markdown]
# <details>
#     <summary>💡 Hint</summary>
#
# - Try to pipeline your preprocessing (PCA) and your modelling (SVC)
# - A pipeline is an instance of Scikit-Learn `Estimator` which hyperparameters can be grid searched
# - Consider `n_components` as an hyperparameter of your pipeline!
#
# </details>

# %%
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC

pipe = make_pipeline(PCA(), SVC(class_weight="balanced"))

param_grid = {
    "pca__n_components": range(200, 600, 1),
    "svc__kernel": ["linear"],
    "svc__C": [10],#[10, 20, 50, 100, 200, 500, 1000, 2000, 5000],
    "svc__gamma": [0.0001]#[0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1],
}
from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(pipe, param_grid, cv=5, n_jobs=-1, scoring='f1_weighted')

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('pca', PCA()), ('svc', SVC(class_weight='balanced'))],
#  'verbose': False,
#  'pca': PCA(),
#  'svc': SVC(class_weight='balanced'),
#  'pca__copy': True,
#  'pca__iterated_power': 'auto',
#  'pca__n_components': None,
#  'pca__random_state': None,
#  'pca__svd_solver': 'auto',
#  'pca__tol': 0.0,
#  'pca__whiten': False,
#  'svc__C': 1.0,
#  'svc__break_ties': False,
#  'svc__cache_size': 200,
#  'svc__class_weight': 'balanced',
#  'svc__coef0': 0.0,
#  'svc__decision_function_shape': 'ovr',
#  'svc__degree': 3,
#  'svc__gamma': 'scale',
#  'svc__kernel': 'rbf',
#  'svc__max_iter': -1,
#  'svc__probability': False,
#  'svc__random_state': None,
#  'svc__shrinking': True,
#  'svc__tol': 0.001,
#  'svc__verbose': False}

# %%
clf = clf.fit(X_train, y_train)

# %%
import pandas as pd
pd.DataFrame(clf.cv_results_).sort_values(by='rank_test_score').head(20)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 273       1.707361      0.027749         0.067437        0.005218
# 126       0.988612      0.047066         0.049474        0.005781
# 129       1.234992      0.059020         0.063641        0.007149
# 289       1.812113      0.056673         0.075951        0.014833
# 326       1.621297      0.012577         0.073283        0.007513
# 269       1.600711      0.026294         0.075099        0.012186
# 294       1.649285      0.107421         0.071962        0.006399
# 365       2.154287      0.103044         0.084173        0.002887
# 313       1.958523      0.087906         0.095048        0.015198
# 328       1.614430      0.033633         0.072263        0.007681
# 270       1.625204      0.059541         0.066609        0.002753
# 134       1.216299      0.023254         0.069400        0.006275
# 277       1.467453      0.021682         0.067701        0.006545
# 272       1.652083      0.050336         0.078411        0.010258
# 147       1.244577      0.012151         0.067220        0.008650
# 348       1.934237      0.027845         0.089534        0.018816
# 113       0.964572      0.018365         0.044373        0.004102
# 135       1.276424      0.010380         0.057574        0.008086
# 180       1.513735      0.071651         0.065028        0.012136
# 234       1.336612      0.073808         0.066039        0.005012
#
#     param_pca__n_components param_svc__C param_svc__gamma param_svc__kernel  \
# 273                     473           10           0.0001            linear
# 126                     326           10           0.0001            linear
# 129                     329           10           0.0001            linear
# 289                     489           10           0.0001            linear
# 326                     526           10           0.0001            linear
# 269                     469           10           0.0001            linear
# 294                     494           10           0.0001            linear
# 365                     565           10           0.0001            linear
# 313                     513           10           0.0001            linear
# 328                     528           10           0.0001            linear
# 270                     470           10           0.0001            linear
# 134                     334           10           0.0001            linear
# 277                     477           10           0.0001            linear
# 272                     472           10           0.0001            linear
# 147                     347           10           0.0001            linear
# 348                     548           10           0.0001            linear
# 113                     313           10           0.0001            linear
# 135                     335           10           0.0001            linear
# 180                     380           10           0.0001            linear
# 234                     434           10           0.0001            linear
#
#                                                 params  split0_test_score  \
# 273  {'pca__n_components': 473, 'svc__C': 10, 'svc_...           0.854125
# 126  {'pca__n_components': 326, 'svc__C': 10, 'svc_...           0.858888
# 129  {'pca__n_components': 329, 'svc__C': 10, 'svc_...           0.859180
# 289  {'pca__n_components': 489, 'svc__C': 10, 'svc_...           0.848591
# 326  {'pca__n_components': 526, 'svc__C': 10, 'svc_...           0.859583
# 269  {'pca__n_components': 469, 'svc__C': 10, 'svc_...           0.848152
# 294  {'pca__n_components': 494, 'svc__C': 10, 'svc_...           0.854125
# 365  {'pca__n_components': 565, 'svc__C': 10, 'svc_...           0.854125
# 313  {'pca__n_components': 513, 'svc__C': 10, 'svc_...           0.854125
# 328  {'pca__n_components': 528, 'svc__C': 10, 'svc_...           0.854125
# 270  {'pca__n_components': 470, 'svc__C': 10, 'svc_...           0.848152
# 134  {'pca__n_components': 334, 'svc__C': 10, 'svc_...           0.859180
# 277  {'pca__n_components': 477, 'svc__C': 10, 'svc_...           0.854125
# 272  {'pca__n_components': 472, 'svc__C': 10, 'svc_...           0.859113
# 147  {'pca__n_components': 347, 'svc__C': 10, 'svc_...           0.853776
# 348  {'pca__n_components': 548, 'svc__C': 10, 'svc_...           0.859583
# 113  {'pca__n_components': 313, 'svc__C': 10, 'svc_...           0.853484
# 135  {'pca__n_components': 335, 'svc__C': 10, 'svc_...           0.859180
# 180  {'pca__n_components': 380, 'svc__C': 10, 'svc_...           0.848193
# 234  {'pca__n_components': 434, 'svc__C': 10, 'svc_...           0.847295
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 273           0.819725           0.832252           0.836396
# 126           0.825247           0.826902           0.842150
# 129           0.825101           0.826902           0.842192
# 289           0.820074           0.832252           0.836396
# 326           0.820074           0.826902           0.830395
# 269           0.820074           0.832252           0.836396
# 294           0.820074           0.832252           0.830395
# 365           0.820074           0.832252           0.830395
# 313           0.820074           0.832252           0.830395
# 328           0.820074           0.832252           0.830395
# 270           0.820074           0.832252           0.842150
# 134           0.819725           0.826902           0.842150
# 277           0.819725           0.832252           0.830395
# 272           0.820074           0.826902           0.836396
# 147           0.825101           0.826902           0.847706
# 348           0.820074           0.832252           0.830395
# 113           0.824674           0.826902           0.842150
# 135           0.820074           0.826902           0.847706
# 180           0.820144           0.832252           0.847706
# 234           0.820074           0.832252           0.842150
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 273           0.821714         0.832842        0.012344                1
# 126           0.810867         0.832811        0.016376                2
# 129           0.810603         0.832796        0.016558                3
# 289           0.821714         0.831805        0.010416                4
# 326           0.821714         0.831734        0.014402                5
# 269           0.821714         0.831717        0.010275                6
# 294           0.821714         0.831712        0.012164                7
# 365           0.821714         0.831712        0.012164                7
# 313           0.821714         0.831712        0.012164                7
# 328           0.821714         0.831712        0.012164                7
# 270           0.815678         0.831661        0.012426               11
# 134           0.810303         0.831652        0.017255               12
# 277           0.821714         0.831642        0.012231               13
# 272           0.815678         0.831633        0.015417               14
# 147           0.804601         0.831617        0.017575               15
# 348           0.815704         0.831602        0.015300               16
# 113           0.810788         0.831600        0.014788               17
# 135           0.804064         0.831585        0.019663               18
# 180           0.809412         0.831541        0.015223               19
# 234           0.815704         0.831495        0.012195               20

# %%
clf.best_estimator_
# Out:
# Pipeline(steps=[('pca', PCA(n_components=473)),
#                 ('svc',
#                  SVC(C=10, class_weight='balanced', gamma=0.0001,
#                      kernel='linear'))])

# %%
clf.best_estimator_.score(X_test, y_test)
# Out:
# 0.8217054263565892

# %%
y_pred = clf.best_estimator_.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.59      0.65        22
#            1       0.81      0.86      0.83        72
#            2       0.67      0.71      0.69        31
#            3       0.87      0.89      0.88       172
#            4       0.81      0.81      0.81        31
#            5       0.77      0.62      0.69        16
#            6       0.82      0.77      0.80        43
#
#     accuracy                           0.82       387
#    macro avg       0.78      0.75      0.76       387
# weighted avg       0.82      0.82      0.82       387

# %% [markdown]
# **❓ How many components give the best score?  Assign the value to a variable called `best_n_components`**

# %%
best_n_components = clf.best_estimator_.get_params()['pca__n_components']
best_n_components
# Out:
# 473

# %% [markdown]
# ### 🧪 Test your code

# %%
from nbresult import ChallengeResult

result = ChallengeResult('classification', best_pc=best_n_components)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.8.12, pytest-6.2.5, py-1.10.0, pluggy-1.0.0 -- /Users/Moe/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/Moe/code/moe221/data-challenges-moe/05-ML/06-Unsupervised-Learning/02-Face-Recognition
# plugins: dash-2.0.0, anyio-3.3.2, cov-3.0.0
# collecting ... collected 1 item
#
# tests/test_classification.py::TestClassification::test_best_pc_number PASSED [100%]
#
# ============================== 1 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/classification.pickle
#
# git commit -m 'Completed classification step'
#
# git push origin master

# %% [markdown]
# 🏁 **Congratulation! Don't forget to commit and push your notebook**
